# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


eps_float32 = np.finfo(np.float32).eps

# %%
class ScaleTrackingCallback(tf.keras.callbacks.Callback):
    def __init__(self, layer):
        super(ScaleTrackingCallback, self).__init__()
        self.layer = layer
        self.scale_values_per_epoch_w = []
        self.average_scale_values_w = []
        self.scale_values_per_epoch_b = []
        self.average_scale_values_b = []

        self.epoch_loss = []
        self.epoch_accuracy = []
        self.num_epochs = 0

    def on_epoch_end(self, epoch, logs=None):
        self.num_epochs += 1
        print("NUMBER OF EPOCHS:", self.num_epochs)
        scale_values_w = self.layer.scale_w.numpy().flatten()
        self.scale_values_per_epoch_w.append(scale_values_w)
        average_scale_value_w = np.mean(scale_values_w)
        self.average_scale_values_w.append(average_scale_value_w)

        scale_values_b = self.layer.scale_b.numpy().flatten()
        self.scale_values_per_epoch_b.append(scale_values_b)
        average_scale_value_b = np.mean(scale_values_b)
        self.average_scale_values_b.append(average_scale_value_b)

        self.epoch_loss.append(logs['loss'])
        self.epoch_accuracy.append(logs['accuracy'])
        print(f"\nEpoch {epoch+1}: Average scale value of w: {average_scale_value_w},Average scale value of b: {average_scale_value_b}, Loss: {logs['loss']}, Accuracy: {logs['accuracy']}")

    def plot_scale_values(self, layer_name):
        plt.figure(figsize=(12, 8))

        # Plot each scale value trajectory
        for i in range(len(self.scale_values_per_epoch_w[0])):
            scale_trajectory = [epoch[i] for epoch in self.scale_values_per_epoch_w]
            plt.plot(range(1, len(self.scale_values_per_epoch_w) + 1), scale_trajectory, linestyle='-', marker='o')

        # Plot the average scale values
        #plt.plot(range(1, len(self.average_scale_values) + 1), self.average_scale_values, label='Average Scale Value', color='red', linewidth=2)

        plt.xlabel('Epochs')
        plt.ylabel('Scale Values')
        plt.title('Scale Values of w per Epoch - ' + layer_name)
        plt.xticks(range(1, len(self.average_scale_values_w) + 1))  
        plt.legend()
        plt.show()

        plt.figure(figsize=(12, 8))

        # Plot each scale value trajectory
        for i in range(len(self.scale_values_per_epoch_b[0])):
            scale_trajectory = [epoch[i] for epoch in self.scale_values_per_epoch_b]
            plt.plot(range(1, len(self.scale_values_per_epoch_b) + 1), scale_trajectory, linestyle='-', marker='o')

        # Plot the average scale values
        #plt.plot(range(1, len(self.average_scale_values) + 1), self.average_scale_values, label='Average Scale Value', color='red', linewidth=2)

        plt.xlabel('Epochs')
        plt.ylabel('Scale Values')
        plt.title('Scale Values of b per Epoch - ' + layer_name)
        plt.xticks(range(1, len(self.average_scale_values_b) + 1))  
        plt.legend()
        plt.show()

    def plot_loss_accuracy(self):
        epochs = range(1, len(self.epoch_loss) + 1)

        plt.figure(figsize=(12, 8))

        plt.subplot(2, 1, 1)
        plt.plot(epochs, self.epoch_loss, 'b-', label='Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss per Epoch')
        plt.xticks(range(1, len(self.average_scale_values_w) + 1))  
        plt.legend()

        plt.subplot(2, 1, 2)
        plt.plot(epochs, self.epoch_accuracy, 'r-', label='Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy per Epoch')
        plt.xticks(range(1, len(self.average_scale_values_w) + 1))  
        plt.legend()

        plt.tight_layout()
        plt.show()

# %%
class ScaleTrackingCallbackInput(tf.keras.callbacks.Callback):
    def __init__(self, layer):
        super(ScaleTrackingCallbackInput, self).__init__()
        self.layer = layer
        self.scale_values_per_epoch = []
        self.average_scale_values = []

    def on_epoch_end(self, epoch, logs=None):
        scale_values_w = self.layer.scale.numpy().flatten()
        self.scale_values_per_epoch.append(scale_values_w)
        average_scale_value_w = np.mean(scale_values_w)
        self.average_scale_values.append(average_scale_value_w)

        print(f"\nEpoch {epoch+1}: Average scale value of input: {average_scale_value_w}")

    def plot_scale_values(self, layer_name):
        plt.figure(figsize=(12, 8))

        # Plot each scale value trajectory
        for i in range(len(self.scale_values_per_epoch[0])):
            scale_trajectory = [epoch[i] for epoch in self.scale_values_per_epoch]
            plt.plot(range(1, len(self.scale_values_per_epoch) + 1), scale_trajectory, linestyle='-', marker='o')

        # Plot the average scale values
        #plt.plot(range(1, len(self.average_scale_values) + 1), self.average_scale_values, label='Average Scale Value', color='red', linewidth=2)

        plt.xlabel('Epochs')
        plt.ylabel('Scale Values')
        plt.title('Scale Values of w per Epoch - ' + layer_name)
        plt.xticks(range(1, len(self.average_scale_values) + 1))  
        plt.legend()
        plt.show()

# %%
# Prepare the data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = np.expand_dims(x_train, -1)  # CNNs typically expect input data to be 4D
x_test = np.expand_dims(x_test, -1)

class LearnedQuantizedDense(tf.keras.layers.Layer):
    def __init__(self, units, activation=None):
        super(LearnedQuantizedDense, self).__init__()
        self.units = units
        self.activation = tf.keras.activations.get(activation)

    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.units), initializer="random_normal", trainable=True)
        self.b = self.add_weight(shape=(self.units,), initializer="random_normal", trainable=True)
        self.scale_w = self.add_weight(shape=(input_shape[-1], 1), initializer="random_normal", trainable=True)
        self.scale_b = self.add_weight(shape=(self.units,), initializer="random_normal", trainable=True)

    def call(self, inputs):
        quantized_w = tf.stop_gradient(tf.floor(self.w / self.scale_w)) + \
                      (self.w / self.scale_w - tf.stop_gradient(self.w / self.scale_w))
        dequantized_w = quantized_w * self.scale_w

        quantized_b = tf.stop_gradient(tf.floor(self.b / self.scale_b)) + \
                      (self.b / self.scale_b - tf.stop_gradient(self.b / self.scale_b))
        dequantized_b = quantized_b * self.scale_b
        
        output = tf.matmul(inputs, dequantized_w) + dequantized_b

        if self.activation is not None:
            output = self.activation(output)
        return output

    def get_scale(self):
        return self.scale_w, self.scale_b

def custom_loss(y_true, y_pred, scales_of_layers):
    cross_entropy_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    
    # small epsilon to avoid division by zero
    epsilon = eps_float32
    scale_penalty = 0
    penalty_rate = 0.1
    for scale_w, scale_b in scales_of_layers:
        scale_penalty += tf.reduce_mean(1.0 / (scale_w + epsilon))
        scale_penalty += tf.reduce_mean(1.0 / (scale_b + epsilon))
    
    # Combine the cross-entropy loss and the scale penalty
    total_loss = cross_entropy_loss + penalty_rate * scale_penalty
    
    return total_loss

input_layer = Input(shape=(28, 28, 1))
flatten_layer = Flatten()(input_layer)
quantized_dense_layer = LearnedQuantizedDense(128, activation='relu')
dense_output = quantized_dense_layer(flatten_layer)
output_layer = LearnedQuantizedDense(10, activation='softmax')(dense_output)

quantized_model = Model(inputs=input_layer, outputs=output_layer)

# Print layer details
for i, layer in enumerate(quantized_model.layers):
    print(f"\nLAYER {i}: {layer}")
    print(f"  - Input Shape: {layer.input_shape}")
    print(f"  - Output Shape: {layer.output_shape}")
    if hasattr(layer, 'get_scale'):
        print(f"  - Scale Shape of w: {layer.get_scale()[0].shape}")
        print(f"  - Scale Shape of b: {layer.get_scale()[1].shape}")


quantized_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=lambda y_true, y_pred: custom_loss(y_true, y_pred, 
                                            [quantized_model.get_layer(index=2).get_scale(), 
                                             quantized_model.get_layer(index=3).get_scale()]),
    metrics=['accuracy']
)

scale_tracking_callback_input_layer = ScaleTrackingCallback(quantized_model.get_layer(index=2))
scale_tracking_callback_dense_layer = ScaleTrackingCallback(quantized_model.get_layer(index=3))

quantized_model.fit(
    x_train, y_train,
    epochs=20,
    validation_data=(x_test, y_test),
    callbacks=[scale_tracking_callback_input_layer,
               scale_tracking_callback_dense_layer]
)

loss, accuracy = quantized_model.evaluate(x_test, y_test)
print(f'Quantized Model Test Accuracy: {accuracy}')

scale_tracking_callback_input_layer.plot_scale_values(layer_name="Quantized Dense Layer 1")
scale_tracking_callback_dense_layer.plot_scale_values(layer_name="Quantized Dense Layer 2")
scale_tracking_callback_dense_layer.plot_loss_accuracy()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# LAYER 0: <keras.src.engine.input_layer.InputLayer object at 0x301892400>
#   - Input Shape: [(None, 28, 28, 1)]
#   - Output Shape: [(None, 28, 28, 1)]
#
# LAYER 1: <keras.src.layers.reshaping.flatten.Flatten object at 0x3019d8c70>
#   - Input Shape: (None, 28, 28, 1)
#   - Output Shape: (None, 784)
#
# LAYER 2: <__main__.LearnedQuantizedDense object at 0x16e90cbe0>
#   - Input Shape: (None, 784)
#   - Output Shape: (None, 128)
#   - Scale Shape of w: (784, 1)
#   - Scale Shape of b: (128,)
#
# LAYER 3: <__main__.LearnedQuantizedDense object at 0x3010e79d0>
#   - Input Shape: (None, 128)
#   - Output Shape: (None, 10)
#   - Scale Shape of w: (128, 1)
#   - Scale Shape of b: (10,)
# Epoch 1/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 19.7428 - accuracy: 0.7597NUMBER OF EPOCHS: 1
#
# Epoch 1: Average scale value of w: 0.10500522702932358,Average scale value of b: 0.18511366844177246, Loss: 19.727256774902344, Accuracy: 0.7600833177566528
# NUMBER OF EPOCHS: 1
#
# Epoch 1: Average scale value of w: 0.10301972925662994,Average scale value of b: 0.186416894197464, Loss: 19.727256774902344, Accuracy: 0.7600833177566528
# 1875/1875 [==============================] - 3s 2ms/step - loss: 19.7273 - accuracy: 0.7601 - val_loss: 15.4853 - val_accuracy: 0.8819
# Epoch 2/20
# 1856/1875 [============================>.] - ETA: 0s - loss: 13.1617 - accuracy: 0.8596NUMBER OF EPOCHS: 2
#
# Epoch 2: Average scale value of w: 0.1568734496831894,Average scale value of b: 0.2963743507862091, Loss: 13.141484260559082, Accuracy: 0.8597833514213562
# NUMBER OF EPOCHS: 2
#
# Epoch 2: Average scale value of w: 0.16337409615516663,Average scale value of b: 0.2829645276069641, Loss: 13.141484260559082, Accuracy: 0.8597833514213562
# 1875/1875 [==============================] - 3s 1ms/step - loss: 13.1415 - accuracy: 0.8598 - val_loss: 11.3522 - val_accuracy: 0.8143
# Epoch 3/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 9.8566 - accuracy: 0.8682NUMBER OF EPOCHS: 3
#
# Epoch 3: Average scale value of w: 0.20788511633872986,Average scale value of b: 0.4239480495452881, Loss: 9.852088928222656, Accuracy: 0.8680499792098999
# NUMBER OF EPOCHS: 3
#
# Epoch 3: Average scale value of w: 0.23285509645938873,Average scale value of b: 0.3760771155357361, Loss: 9.852088928222656, Accuracy: 0.8680499792098999
# 1875/1875 [==============================] - 3s 1ms/step - loss: 9.8521 - accuracy: 0.8680 - val_loss: 8.6813 - val_accuracy: 0.8774
# Epoch 4/20
# 1854/1875 [============================>.] - ETA: 0s - loss: 7.7117 - accuracy: 0.8695NUMBER OF EPOCHS: 4
#
# Epoch 4: Average scale value of w: 0.26406821608543396,Average scale value of b: 0.5835434198379517, Loss: 7.7020039558410645, Accuracy: 0.869533360004425
# NUMBER OF EPOCHS: 4
#
# Epoch 4: Average scale value of w: 0.32201462984085083,Average scale value of b: 0.455928236246109, Loss: 7.7020039558410645, Accuracy: 0.869533360004425
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.7020 - accuracy: 0.8695 - val_loss: 6.8035 - val_accuracy: 0.8799
# Epoch 5/20
# 1840/1875 [============================>.] - ETA: 0s - loss: 6.1158 - accuracy: 0.8693NUMBER OF EPOCHS: 5
#
# Epoch 5: Average scale value of w: 0.3251059651374817,Average scale value of b: 0.786772608757019, Loss: 6.1032538414001465, Accuracy: 0.8693666458129883
# NUMBER OF EPOCHS: 5
#
# Epoch 5: Average scale value of w: 0.4397357106208801,Average scale value of b: 0.5218874216079712, Loss: 6.1032538414001465, Accuracy: 0.8693666458129883
# 1875/1875 [==============================] - 3s 1ms/step - loss: 6.1033 - accuracy: 0.8694 - val_loss: 5.5269 - val_accuracy: 0.8766
# Epoch 6/20
# 1840/1875 [============================>.] - ETA: 0s - loss: 4.8647 - accuracy: 0.8638NUMBER OF EPOCHS: 6
#
# Epoch 6: Average scale value of w: 0.39861616492271423,Average scale value of b: 1.041805624961853, Loss: 4.85612678527832, Accuracy: 0.8633166551589966
# NUMBER OF EPOCHS: 6
#
# Epoch 6: Average scale value of w: 0.5950109362602234,Average scale value of b: 0.575128436088562, Loss: 4.85612678527832, Accuracy: 0.8633166551589966
# 1875/1875 [==============================] - 3s 1ms/step - loss: 4.8561 - accuracy: 0.8633 - val_loss: 4.4717 - val_accuracy: 0.8563
# Epoch 7/20
# 1870/1875 [============================>.] - ETA: 0s - loss: 3.8707 - accuracy: 0.8630NUMBER OF EPOCHS: 7
#
# Epoch 7: Average scale value of w: 0.4787777364253998,Average scale value of b: 1.3579847812652588, Loss: 3.8700594902038574, Accuracy: 0.8628166913986206
# NUMBER OF EPOCHS: 7
#
# Epoch 7: Average scale value of w: 0.799916684627533,Average scale value of b: 0.6260788440704346, Loss: 3.8700594902038574, Accuracy: 0.8628166913986206
# 1875/1875 [==============================] - 3s 1ms/step - loss: 3.8701 - accuracy: 0.8628 - val_loss: 3.6363 - val_accuracy: 0.8238
# Epoch 8/20
# 1846/1875 [============================>.] - ETA: 0s - loss: 3.1236 - accuracy: 0.8596NUMBER OF EPOCHS: 8
#
# Epoch 8: Average scale value of w: 0.5735495686531067,Average scale value of b: 1.7407824993133545, Loss: 3.1176669597625732, Accuracy: 0.8597666621208191
# NUMBER OF EPOCHS: 8
#
# Epoch 8: Average scale value of w: 1.068137288093567,Average scale value of b: 0.6698030233383179, Loss: 3.1176669597625732, Accuracy: 0.8597666621208191
# 1875/1875 [==============================] - 2s 1ms/step - loss: 3.1177 - accuracy: 0.8598 - val_loss: 2.8731 - val_accuracy: 0.8670
# Epoch 9/20
# 1869/1875 [============================>.] - ETA: 0s - loss: 2.5444 - accuracy: 0.8584NUMBER OF EPOCHS: 9
#
# Epoch 9: Average scale value of w: 0.6751948595046997,Average scale value of b: 2.191666603088379, Loss: 2.544191598892212, Accuracy: 0.8583333492279053
# NUMBER OF EPOCHS: 9
#
# Epoch 9: Average scale value of w: 1.4099112749099731,Average scale value of b: 0.7361207604408264, Loss: 2.544191598892212, Accuracy: 0.8583333492279053
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.5442 - accuracy: 0.8583 - val_loss: 3.1316 - val_accuracy: 0.8258
# Epoch 10/20
# 1834/1875 [============================>.] - ETA: 0s - loss: 2.1445 - accuracy: 0.8595NUMBER OF EPOCHS: 10
#
# Epoch 10: Average scale value of w: 0.7964267134666443,Average scale value of b: 2.7108473777770996, Loss: 2.1395370960235596, Accuracy: 0.859666645526886
# NUMBER OF EPOCHS: 10
#
# Epoch 10: Average scale value of w: 1.8315534591674805,Average scale value of b: 0.8325080871582031, Loss: 2.1395370960235596, Accuracy: 0.859666645526886
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.1395 - accuracy: 0.8597 - val_loss: 2.1229 - val_accuracy: 0.8668
# Epoch 11/20
# 1875/1875 [==============================] - ETA: 0s - loss: 1.8352 - accuracy: 0.8508NUMBER OF EPOCHS: 11
#
# Epoch 11: Average scale value of w: 0.9270785450935364,Average scale value of b: 3.2954587936401367, Loss: 1.8352136611938477, Accuracy: 0.8507833480834961
# NUMBER OF EPOCHS: 11
#
# Epoch 11: Average scale value of w: 2.339806079864502,Average scale value of b: 0.9078398942947388, Loss: 1.8352136611938477, Accuracy: 0.8507833480834961
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.8352 - accuracy: 0.8508 - val_loss: 1.8617 - val_accuracy: 0.8714
# Epoch 12/20
# 1871/1875 [============================>.] - ETA: 0s - loss: 1.6323 - accuracy: 0.8466NUMBER OF EPOCHS: 12
#
# Epoch 12: Average scale value of w: 1.0754324197769165,Average scale value of b: 3.942734479904175, Loss: 1.6320711374282837, Accuracy: 0.8466333150863647
# NUMBER OF EPOCHS: 12
#
# Epoch 12: Average scale value of w: 2.930689811706543,Average scale value of b: 1.0131386518478394, Loss: 1.6320711374282837, Accuracy: 0.8466333150863647
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.6321 - accuracy: 0.8466 - val_loss: 1.6478 - val_accuracy: 0.8426
# Epoch 13/20
# 1837/1875 [============================>.] - ETA: 0s - loss: 1.4744 - accuracy: 0.8418NUMBER OF EPOCHS: 13
#
# Epoch 13: Average scale value of w: 1.2307103872299194,Average scale value of b: 4.655032634735107, Loss: 1.4698349237442017, Accuracy: 0.8417333364486694
# NUMBER OF EPOCHS: 13
#
# Epoch 13: Average scale value of w: 3.6049928665161133,Average scale value of b: 1.1702072620391846, Loss: 1.4698349237442017, Accuracy: 0.8417333364486694
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.4698 - accuracy: 0.8417 - val_loss: 1.5103 - val_accuracy: 0.8237
# Epoch 14/20
# 1867/1875 [============================>.] - ETA: 0s - loss: 1.3580 - accuracy: 0.8307NUMBER OF EPOCHS: 14
#
# Epoch 14: Average scale value of w: 1.3937103748321533,Average scale value of b: 5.433632850646973, Loss: 1.3564172983169556, Accuracy: 0.8308666944503784
# NUMBER OF EPOCHS: 14
#
# Epoch 14: Average scale value of w: 4.359749794006348,Average scale value of b: 1.2687410116195679, Loss: 1.3564172983169556, Accuracy: 0.8308666944503784
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.3564 - accuracy: 0.8309 - val_loss: 1.5125 - val_accuracy: 0.8459
# Epoch 15/20
# 1854/1875 [============================>.] - ETA: 0s - loss: 1.2864 - accuracy: 0.8379NUMBER OF EPOCHS: 15
#
# Epoch 15: Average scale value of w: 1.569077491760254,Average scale value of b: 6.28306770324707, Loss: 1.2843588590621948, Accuracy: 0.837933361530304
# NUMBER OF EPOCHS: 15
#
# Epoch 15: Average scale value of w: 5.1959228515625,Average scale value of b: 1.3731197118759155, Loss: 1.2843588590621948, Accuracy: 0.837933361530304
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.2844 - accuracy: 0.8379 - val_loss: 1.3920 - val_accuracy: 0.8255
# Epoch 16/20
# 1849/1875 [============================>.] - ETA: 0s - loss: 1.2347 - accuracy: 0.8315NUMBER OF EPOCHS: 16
#
# Epoch 16: Average scale value of w: 1.7586523294448853,Average scale value of b: 7.210078716278076, Loss: 1.2322733402252197, Accuracy: 0.8317333459854126
# NUMBER OF EPOCHS: 16
#
# Epoch 16: Average scale value of w: 6.114187240600586,Average scale value of b: 1.4577014446258545, Loss: 1.2322733402252197, Accuracy: 0.8317333459854126
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.2323 - accuracy: 0.8317 - val_loss: 1.4662 - val_accuracy: 0.8321
# Epoch 17/20
# 1845/1875 [============================>.] - ETA: 0s - loss: 1.1714 - accuracy: 0.8331NUMBER OF EPOCHS: 17
#
# Epoch 17: Average scale value of w: 1.955460786819458,Average scale value of b: 8.215533256530762, Loss: 1.172529697418213, Accuracy: 0.8329166769981384
# NUMBER OF EPOCHS: 17
#
# Epoch 17: Average scale value of w: 7.116445064544678,Average scale value of b: 1.4767966270446777, Loss: 1.172529697418213, Accuracy: 0.8329166769981384
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1725 - accuracy: 0.8329 - val_loss: 1.4394 - val_accuracy: 0.8019
# Epoch 18/20
# 1866/1875 [============================>.] - ETA: 0s - loss: 1.1526 - accuracy: 0.8199NUMBER OF EPOCHS: 18
#
# Epoch 18: Average scale value of w: 2.1574831008911133,Average scale value of b: 9.301288604736328, Loss: 1.1527265310287476, Accuracy: 0.819683313369751
# NUMBER OF EPOCHS: 18
#
# Epoch 18: Average scale value of w: 8.197244644165039,Average scale value of b: 1.499603033065796, Loss: 1.1527265310287476, Accuracy: 0.819683313369751
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1527 - accuracy: 0.8197 - val_loss: 1.3738 - val_accuracy: 0.7373
# Epoch 19/20
# 1840/1875 [============================>.] - ETA: 0s - loss: 1.1386 - accuracy: 0.8182NUMBER OF EPOCHS: 19
#
# Epoch 19: Average scale value of w: 2.3637149333953857,Average scale value of b: 10.458596229553223, Loss: 1.1378036737442017, Accuracy: 0.8185166716575623
# NUMBER OF EPOCHS: 19
#
# Epoch 19: Average scale value of w: 9.351959228515625,Average scale value of b: 1.5727522373199463, Loss: 1.1378036737442017, Accuracy: 0.8185166716575623
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1378 - accuracy: 0.8185 - val_loss: 1.5070 - val_accuracy: 0.8690
# Epoch 20/20
# 1844/1875 [============================>.] - ETA: 0s - loss: 1.1015 - accuracy: 0.8267NUMBER OF EPOCHS: 20
#
# Epoch 20: Average scale value of w: 2.587880849838257,Average scale value of b: 11.670480728149414, Loss: 1.1013633012771606, Accuracy: 0.8264999985694885
# NUMBER OF EPOCHS: 20
#
# Epoch 20: Average scale value of w: 10.570079803466797,Average scale value of b: 1.6927239894866943, Loss: 1.1013633012771606, Accuracy: 0.8264999985694885
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1014 - accuracy: 0.8265 - val_loss: 1.2755 - val_accuracy: 0.8009
# 313/313 [==============================] - 0s 592us/step - loss: 1.2755 - accuracy: 0.8009
# Quantized Model Test Accuracy: 0.8008999824523926
# /var/folders/ms/xd16k27j2lj0dx3xp_nqkcgr0000gn/T/ipykernel_811/76854052.py:46: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/ms/xd16k27j2lj0dx3xp_nqkcgr0000gn/T/ipykernel_811/76854052.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Print layer details
for i, layer in enumerate(quantized_model.layers):
    print(f"\nLAYER {i}: {layer}")
    print(f"  - Input Shape: {layer.input_shape}")
    print(f"  - Output Shape: {layer.output_shape}")
    if hasattr(layer, 'get_scale'):
        print(f"  - Scale Shape of w: {layer.get_scale()[0].shape}")
        print(f"  - Scale Shape of b: {layer.get_scale()[1].shape}")
# Out:
# LAYER 0: <keras.src.engine.input_layer.InputLayer object at 0x301892400>
#   - Input Shape: [(None, 28, 28, 1)]
#   - Output Shape: [(None, 28, 28, 1)]
#
# LAYER 1: <keras.src.layers.reshaping.flatten.Flatten object at 0x3019d8c70>
#   - Input Shape: (None, 28, 28, 1)
#   - Output Shape: (None, 784)
#
# LAYER 2: <__main__.LearnedQuantizedDense object at 0x16e90cbe0>
#   - Input Shape: (None, 784)
#   - Output Shape: (None, 128)
#   - Scale Shape of w: (784, 1)
#   - Scale Shape of b: (128,)
#
# LAYER 3: <__main__.LearnedQuantizedDense object at 0x3010e79d0>
#   - Input Shape: (None, 128)
#   - Output Shape: (None, 10)
#   - Scale Shape of w: (128, 1)
#   - Scale Shape of b: (10,)
