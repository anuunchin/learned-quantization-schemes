# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


eps_float32 = np.finfo(np.float32).eps

# %%
class ScaleTrackingCallback(tf.keras.callbacks.Callback):
    def __init__(self, layer):
        super(ScaleTrackingCallback, self).__init__()
        self.layer = layer
        self.scale_values_per_epoch_w = []
        self.average_scale_values_w = []
        self.scale_values_per_epoch_b = []
        self.average_scale_values_b = []

        self.epoch_loss = []
        self.epoch_accuracy = []
        self.num_epochs = 0

    def on_epoch_end(self, epoch, logs=None):
        self.num_epochs += 1
        print("NUMBER OF EPOCHS:", self.num_epochs)
        scale_values_w = self.layer.scale_w.numpy().flatten()
        self.scale_values_per_epoch_w.append(scale_values_w)
        average_scale_value_w = np.mean(scale_values_w)
        self.average_scale_values_w.append(average_scale_value_w)

        scale_values_b = self.layer.scale_b.numpy().flatten()
        self.scale_values_per_epoch_b.append(scale_values_b)
        average_scale_value_b = np.mean(scale_values_b)
        self.average_scale_values_b.append(average_scale_value_b)

        self.epoch_loss.append(logs['loss'])
        self.epoch_accuracy.append(logs['accuracy'])
        print(f"\nEpoch {epoch+1}: Average scale value of w: {average_scale_value_w},Average scale value of b: {average_scale_value_b}, Loss: {logs['loss']}, Accuracy: {logs['accuracy']}")

    def plot_scale_values(self, layer_name):
        plt.figure(figsize=(12, 8))

        # Plot each scale value trajectory
        for i in range(len(self.scale_values_per_epoch_w[0])):
            scale_trajectory = [epoch[i] for epoch in self.scale_values_per_epoch_w]
            plt.plot(range(1, len(self.scale_values_per_epoch_w) + 1), scale_trajectory, linestyle='-', marker='o')

        # Plot the average scale values
        #plt.plot(range(1, len(self.average_scale_values) + 1), self.average_scale_values, label='Average Scale Value', color='red', linewidth=2)

        plt.xlabel('Epochs')
        plt.ylabel('Scale Values')
        plt.title('Scale Values of w per Epoch - ' + layer_name)
        plt.xticks(range(1, len(self.average_scale_values_w) + 1))  
        plt.legend()
        plt.show()

        plt.figure(figsize=(12, 8))

        # Plot each scale value trajectory
        for i in range(len(self.scale_values_per_epoch_b[0])):
            scale_trajectory = [epoch[i] for epoch in self.scale_values_per_epoch_b]
            plt.plot(range(1, len(self.scale_values_per_epoch_b) + 1), scale_trajectory, linestyle='-', marker='o')

        # Plot the average scale values
        #plt.plot(range(1, len(self.average_scale_values) + 1), self.average_scale_values, label='Average Scale Value', color='red', linewidth=2)

        plt.xlabel('Epochs')
        plt.ylabel('Scale Values')
        plt.title('Scale Values of b per Epoch - ' + layer_name)
        plt.xticks(range(1, len(self.average_scale_values_b) + 1))  
        plt.legend()
        plt.show()

    def plot_loss_accuracy(self):
        epochs = range(1, len(self.epoch_loss) + 1)

        plt.figure(figsize=(12, 8))

        plt.subplot(2, 1, 1)
        plt.plot(epochs, self.epoch_loss, 'b-', label='Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss per Epoch')
        plt.xticks(range(1, len(self.average_scale_values_w) + 1))  
        plt.legend()

        plt.subplot(2, 1, 2)
        plt.plot(epochs, self.epoch_accuracy, 'r-', label='Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy per Epoch')
        plt.xticks(range(1, len(self.average_scale_values_w) + 1))  
        plt.legend()

        plt.tight_layout()
        plt.show()

# %%
class ScaleTrackingCallbackInput(tf.keras.callbacks.Callback):
    def __init__(self, layer):
        super(ScaleTrackingCallbackInput, self).__init__()
        self.layer = layer
        self.scale_values_per_epoch = []
        self.average_scale_values = []

    def on_epoch_end(self, epoch, logs=None):
        scale_values_w = self.layer.scale.numpy().flatten()
        self.scale_values_per_epoch.append(scale_values_w)
        average_scale_value_w = np.mean(scale_values_w)
        self.average_scale_values.append(average_scale_value_w)

        print(f"\nEpoch {epoch+1}: Average scale value of input: {average_scale_value_w}")

    def plot_scale_values(self, layer_name):
        plt.figure(figsize=(12, 8))

        # Plot each scale value trajectory
        for i in range(len(self.scale_values_per_epoch[0])):
            scale_trajectory = [epoch[i] for epoch in self.scale_values_per_epoch]
            plt.plot(range(1, len(self.scale_values_per_epoch) + 1), scale_trajectory, linestyle='-', marker='o')

        # Plot the average scale values
        #plt.plot(range(1, len(self.average_scale_values) + 1), self.average_scale_values, label='Average Scale Value', color='red', linewidth=2)

        plt.xlabel('Epochs')
        plt.ylabel('Scale Values')
        plt.title('Scale Values of w per Epoch - ' + layer_name)
        plt.xticks(range(1, len(self.average_scale_values) + 1))  
        plt.legend()
        plt.show()

# %%
# Prepare the data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = np.expand_dims(x_train, -1)  # CNNs typically expect input data to be 4D
x_test = np.expand_dims(x_test, -1)

class LearnedQuantizedDense(tf.keras.layers.Layer):
    def __init__(self, units, activation=None):
        super(LearnedQuantizedDense, self).__init__()
        self.units = units
        self.activation = tf.keras.activations.get(activation)

    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.units), initializer="random_normal", trainable=True)
        self.b = self.add_weight(shape=(self.units,), initializer="random_normal", trainable=True)
        self.scale_w = self.add_weight(shape=(input_shape[-1], 1), initializer="random_normal", trainable=True)
        self.scale_b = self.add_weight(shape=(self.units,), initializer="random_normal", trainable=True)

    def call(self, inputs):
        quantized_w = tf.stop_gradient(tf.round(self.w / self.scale_w)) + \
                      (self.w / self.scale_w - tf.stop_gradient(self.w / self.scale_w))
        dequantized_w = quantized_w * self.scale_w

        quantized_b = tf.stop_gradient(tf.round(self.b / self.scale_b)) + \
                      (self.b / self.scale_b - tf.stop_gradient(self.b / self.scale_b))
        dequantized_b = quantized_b * self.scale_b
        
        output = tf.matmul(inputs, dequantized_w) + dequantized_b

        if self.activation is not None:
            output = self.activation(output)
        return output

    def get_scale(self):
        return self.scale_w, self.scale_b

def custom_loss(y_true, y_pred, scales_of_layers):
    cross_entropy_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    
    # small epsilon to avoid division by zero
    epsilon = eps_float32
    scale_penalty = 0
    penalty_rate = 0.1
    for scale_w, scale_b in scales_of_layers:
        scale_penalty += tf.reduce_mean(1.0 / (scale_w + epsilon))
        scale_penalty += tf.reduce_mean(1.0 / (scale_b + epsilon))
    
    # Combine the cross-entropy loss and the scale penalty
    total_loss = cross_entropy_loss + penalty_rate * scale_penalty
    
    return total_loss

input_layer = Input(shape=(28, 28, 1))
flatten_layer = Flatten()(input_layer)
quantized_dense_layer = LearnedQuantizedDense(128, activation='relu')
dense_output = quantized_dense_layer(flatten_layer)
output_layer = LearnedQuantizedDense(10, activation='softmax')(dense_output)

quantized_model = Model(inputs=input_layer, outputs=output_layer)

# Print layer details
for i, layer in enumerate(quantized_model.layers):
    print(f"\nLAYER {i}: {layer}")
    print(f"  - Input Shape: {layer.input_shape}")
    print(f"  - Output Shape: {layer.output_shape}")
    if hasattr(layer, 'get_scale'):
        print(f"  - Scale Shape: {layer.get_scale()[0].shape}")


quantized_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=lambda y_true, y_pred: custom_loss(y_true, y_pred, 
                                            [quantized_model.get_layer(index=2).get_scale(), 
                                             quantized_model.get_layer(index=3).get_scale()]),
    metrics=['accuracy']
)

scale_tracking_callback_input_layer = ScaleTrackingCallback(quantized_model.get_layer(index=2))
scale_tracking_callback_dense_layer = ScaleTrackingCallback(quantized_model.get_layer(index=3))

quantized_model.fit(
    x_train, y_train,
    epochs=20,
    validation_data=(x_test, y_test),
    callbacks=[scale_tracking_callback_input_layer,
               scale_tracking_callback_dense_layer]
)

loss, accuracy = quantized_model.evaluate(x_test, y_test)
print(f'Quantized Model Test Accuracy: {accuracy}')

scale_tracking_callback_input_layer.plot_scale_values(layer_name="Quantized Dense Layer")
scale_tracking_callback_dense_layer.plot_scale_values(layer_name="Quantized Dense Layer")
scale_tracking_callback_dense_layer.plot_loss_accuracy()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# LAYER 0: <keras.src.engine.input_layer.InputLayer object at 0x16e90c9d0>
#   - Input Shape: [(None, 28, 28, 1)]
#   - Output Shape: [(None, 28, 28, 1)]
#
# LAYER 1: <keras.src.layers.reshaping.flatten.Flatten object at 0x3019bdc40>
#   - Input Shape: (None, 28, 28, 1)
#   - Output Shape: (None, 784)
#
# LAYER 2: <__main__.LearnedQuantizedDense object at 0x301631730>
#   - Input Shape: (None, 784)
#   - Output Shape: (None, 128)
#   - Scale Shape: (784, 1)
#
# LAYER 3: <__main__.LearnedQuantizedDense object at 0x31ca13730>
#   - Input Shape: (None, 128)
#   - Output Shape: (None, 10)
#   - Scale Shape: (128, 1)
# Epoch 1/20
# 1852/1875 [============================>.] - ETA: 0s - loss: 17.7801 - accuracy: 0.8581NUMBER OF EPOCHS: 1
#
# Epoch 1: Average scale value of w: 0.10809978097677231,Average scale value of b: 0.21992278099060059, Loss: 17.725059509277344, Accuracy: 0.8585000038146973
# NUMBER OF EPOCHS: 1
#
# Epoch 1: Average scale value of w: 0.10216712206602097,Average scale value of b: 0.1941792219877243, Loss: 17.725059509277344, Accuracy: 0.8585000038146973
# 1875/1875 [==============================] - 3s 1ms/step - loss: 17.7251 - accuracy: 0.8585 - val_loss: 13.3321 - val_accuracy: 0.8735
# Epoch 2/20
# 1853/1875 [============================>.] - ETA: 0s - loss: 11.0245 - accuracy: 0.8961NUMBER OF EPOCHS: 2
#
# Epoch 2: Average scale value of w: 0.1640986204147339,Average scale value of b: 0.35243159532546997, Loss: 11.003293991088867, Accuracy: 0.896316647529602
# NUMBER OF EPOCHS: 2
#
# Epoch 2: Average scale value of w: 0.16043484210968018,Average scale value of b: 0.30878448486328125, Loss: 11.003293991088867, Accuracy: 0.896316647529602
# 1875/1875 [==============================] - 3s 1ms/step - loss: 11.0033 - accuracy: 0.8963 - val_loss: 9.2404 - val_accuracy: 0.8965
# Epoch 3/20
# 1854/1875 [============================>.] - ETA: 0s - loss: 7.9559 - accuracy: 0.9017NUMBER OF EPOCHS: 3
#
# Epoch 3: Average scale value of w: 0.2220504879951477,Average scale value of b: 0.5045762062072754, Loss: 7.9443488121032715, Accuracy: 0.9013833403587341
# NUMBER OF EPOCHS: 3
#
# Epoch 3: Average scale value of w: 0.22347000241279602,Average scale value of b: 0.4370100498199463, Loss: 7.9443488121032715, Accuracy: 0.9013833403587341
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.9443 - accuracy: 0.9014 - val_loss: 6.9244 - val_accuracy: 0.8729
# Epoch 4/20
# 1861/1875 [============================>.] - ETA: 0s - loss: 6.0479 - accuracy: 0.9017NUMBER OF EPOCHS: 4
#
# Epoch 4: Average scale value of w: 0.2846486568450928,Average scale value of b: 0.6964772939682007, Loss: 6.042535305023193, Accuracy: 0.9015166759490967
# NUMBER OF EPOCHS: 4
#
# Epoch 4: Average scale value of w: 0.294182687997818,Average scale value of b: 0.5787646174430847, Loss: 6.042535305023193, Accuracy: 0.9015166759490967
# 1875/1875 [==============================] - 3s 2ms/step - loss: 6.0425 - accuracy: 0.9015 - val_loss: 5.2887 - val_accuracy: 0.8929
# Epoch 5/20
# 1837/1875 [============================>.] - ETA: 0s - loss: 4.7120 - accuracy: 0.9017NUMBER OF EPOCHS: 5
#
# Epoch 5: Average scale value of w: 0.3564932346343994,Average scale value of b: 0.9444758892059326, Loss: 4.703044891357422, Accuracy: 0.9014000296592712
# NUMBER OF EPOCHS: 5
#
# Epoch 5: Average scale value of w: 0.37481409311294556,Average scale value of b: 0.7275195121765137, Loss: 4.703044891357422, Accuracy: 0.9014000296592712
# 1875/1875 [==============================] - 3s 1ms/step - loss: 4.7030 - accuracy: 0.9014 - val_loss: 4.2255 - val_accuracy: 0.9076
# Epoch 6/20
# 1865/1875 [============================>.] - ETA: 0s - loss: 3.7067 - accuracy: 0.9002NUMBER OF EPOCHS: 6
#
# Epoch 6: Average scale value of w: 0.4387952387332916,Average scale value of b: 1.26323664188385, Loss: 3.7057762145996094, Accuracy: 0.9001666903495789
# NUMBER OF EPOCHS: 6
#
# Epoch 6: Average scale value of w: 0.46627119183540344,Average scale value of b: 0.8635636568069458, Loss: 3.7057762145996094, Accuracy: 0.9001666903495789
# 1875/1875 [==============================] - 3s 1ms/step - loss: 3.7058 - accuracy: 0.9002 - val_loss: 3.4619 - val_accuracy: 0.9076
# Epoch 7/20
# 1844/1875 [============================>.] - ETA: 0s - loss: 2.9974 - accuracy: 0.8979NUMBER OF EPOCHS: 7
#
# Epoch 7: Average scale value of w: 0.5326638221740723,Average scale value of b: 1.6640758514404297, Loss: 2.990826368331909, Accuracy: 0.8980833292007446
# NUMBER OF EPOCHS: 7
#
# Epoch 7: Average scale value of w: 0.5786269903182983,Average scale value of b: 0.9571255445480347, Loss: 2.990826368331909, Accuracy: 0.8980833292007446
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.9908 - accuracy: 0.8981 - val_loss: 2.8089 - val_accuracy: 0.8859
# Epoch 8/20
# 1860/1875 [============================>.] - ETA: 0s - loss: 2.4804 - accuracy: 0.8920NUMBER OF EPOCHS: 8
#
# Epoch 8: Average scale value of w: 0.6345348954200745,Average scale value of b: 2.1520748138427734, Loss: 2.4780726432800293, Accuracy: 0.8919000029563904
# NUMBER OF EPOCHS: 8
#
# Epoch 8: Average scale value of w: 0.7077996730804443,Average scale value of b: 1.0497995615005493, Loss: 2.4780726432800293, Accuracy: 0.8919000029563904
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.4781 - accuracy: 0.8919 - val_loss: 2.2914 - val_accuracy: 0.9001
# Epoch 9/20
# 1839/1875 [============================>.] - ETA: 0s - loss: 2.1108 - accuracy: 0.8762NUMBER OF EPOCHS: 9
#
# Epoch 9: Average scale value of w: 0.7499987483024597,Average scale value of b: 2.727391242980957, Loss: 2.106692314147949, Accuracy: 0.8761000037193298
# NUMBER OF EPOCHS: 9
#
# Epoch 9: Average scale value of w: 0.8658326864242554,Average scale value of b: 1.0254077911376953, Loss: 2.106692314147949, Accuracy: 0.8761000037193298
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.1067 - accuracy: 0.8761 - val_loss: 2.0533 - val_accuracy: 0.8855
# Epoch 10/20
# 1858/1875 [============================>.] - ETA: 0s - loss: 1.7911 - accuracy: 0.8807NUMBER OF EPOCHS: 10
#
# Epoch 10: Average scale value of w: 0.8822438716888428,Average scale value of b: 3.3828060626983643, Loss: 1.7887754440307617, Accuracy: 0.8806999921798706
# NUMBER OF EPOCHS: 10
#
# Epoch 10: Average scale value of w: 1.0468473434448242,Average scale value of b: 1.081932783126831, Loss: 1.7887754440307617, Accuracy: 0.8806999921798706
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.7888 - accuracy: 0.8807 - val_loss: 1.8568 - val_accuracy: 0.8748
# Epoch 11/20
# 1852/1875 [============================>.] - ETA: 0s - loss: 1.5715 - accuracy: 0.8886NUMBER OF EPOCHS: 11
#
# Epoch 11: Average scale value of w: 1.0266562700271606,Average scale value of b: 4.109576225280762, Loss: 1.570107340812683, Accuracy: 0.8886500000953674
# NUMBER OF EPOCHS: 11
#
# Epoch 11: Average scale value of w: 1.2441082000732422,Average scale value of b: 1.1738286018371582, Loss: 1.570107340812683, Accuracy: 0.8886500000953674
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.5701 - accuracy: 0.8887 - val_loss: 1.6056 - val_accuracy: 0.8744
# Epoch 12/20
# 1863/1875 [============================>.] - ETA: 0s - loss: 1.4403 - accuracy: 0.8735NUMBER OF EPOCHS: 12
#
# Epoch 12: Average scale value of w: 1.1772314310073853,Average scale value of b: 4.900472640991211, Loss: 1.4413607120513916, Accuracy: 0.8735666871070862
# NUMBER OF EPOCHS: 12
#
# Epoch 12: Average scale value of w: 1.4609670639038086,Average scale value of b: 1.252245545387268, Loss: 1.4413607120513916, Accuracy: 0.8735666871070862
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.4414 - accuracy: 0.8736 - val_loss: 1.6337 - val_accuracy: 0.8911
# Epoch 13/20
# 1845/1875 [============================>.] - ETA: 0s - loss: 1.2988 - accuracy: 0.8788NUMBER OF EPOCHS: 13
#
# Epoch 13: Average scale value of w: 1.3385531902313232,Average scale value of b: 5.749541282653809, Loss: 1.298020839691162, Accuracy: 0.8781166672706604
# NUMBER OF EPOCHS: 13
#
# Epoch 13: Average scale value of w: 1.689820408821106,Average scale value of b: 1.4053733348846436, Loss: 1.298020839691162, Accuracy: 0.8781166672706604
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.2980 - accuracy: 0.8781 - val_loss: 1.3337 - val_accuracy: 0.8801
# Epoch 14/20
# 1865/1875 [============================>.] - ETA: 0s - loss: 1.2378 - accuracy: 0.8764NUMBER OF EPOCHS: 14
#
# Epoch 14: Average scale value of w: 1.5015432834625244,Average scale value of b: 6.658560752868652, Loss: 1.2372066974639893, Accuracy: 0.8765833377838135
# NUMBER OF EPOCHS: 14
#
# Epoch 14: Average scale value of w: 1.931266188621521,Average scale value of b: 1.584771752357483, Loss: 1.2372066974639893, Accuracy: 0.8765833377838135
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.2372 - accuracy: 0.8766 - val_loss: 1.3030 - val_accuracy: 0.8864
# Epoch 15/20
# 1861/1875 [============================>.] - ETA: 0s - loss: 1.1690 - accuracy: 0.8710NUMBER OF EPOCHS: 15
#
# Epoch 15: Average scale value of w: 1.671164631843567,Average scale value of b: 7.627399921417236, Loss: 1.171602725982666, Accuracy: 0.8710333108901978
# NUMBER OF EPOCHS: 15
#
# Epoch 15: Average scale value of w: 2.1857919692993164,Average scale value of b: 1.7376047372817993, Loss: 1.171602725982666, Accuracy: 0.8710333108901978
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1716 - accuracy: 0.8710 - val_loss: 1.2890 - val_accuracy: 0.8793
# Epoch 16/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 1.1511 - accuracy: 0.8663NUMBER OF EPOCHS: 16
#
# Epoch 16: Average scale value of w: 1.840527892112732,Average scale value of b: 8.657201766967773, Loss: 1.1505464315414429, Accuracy: 0.8662833571434021
# NUMBER OF EPOCHS: 16
#
# Epoch 16: Average scale value of w: 2.461381435394287,Average scale value of b: 1.89480721950531, Loss: 1.1505464315414429, Accuracy: 0.8662833571434021
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1505 - accuracy: 0.8663 - val_loss: 1.3448 - val_accuracy: 0.8352
# Epoch 17/20
# 1851/1875 [============================>.] - ETA: 0s - loss: 1.1333 - accuracy: 0.8645NUMBER OF EPOCHS: 17
#
# Epoch 17: Average scale value of w: 2.01849365234375,Average scale value of b: 9.763754844665527, Loss: 1.133166790008545, Accuracy: 0.8644333481788635
# NUMBER OF EPOCHS: 17
#
# Epoch 17: Average scale value of w: 2.769009590148926,Average scale value of b: 2.0556843280792236, Loss: 1.133166790008545, Accuracy: 0.8644333481788635
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1332 - accuracy: 0.8644 - val_loss: 1.2564 - val_accuracy: 0.8063
# Epoch 18/20
# 1860/1875 [============================>.] - ETA: 0s - loss: 1.1192 - accuracy: 0.8639NUMBER OF EPOCHS: 18
#
# Epoch 18: Average scale value of w: 2.1994259357452393,Average scale value of b: 10.943367004394531, Loss: 1.1186760663986206, Accuracy: 0.8637333512306213
# NUMBER OF EPOCHS: 18
#
# Epoch 18: Average scale value of w: 3.11000919342041,Average scale value of b: 2.2149269580841064, Loss: 1.1186760663986206, Accuracy: 0.8637333512306213
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1187 - accuracy: 0.8637 - val_loss: 1.2441 - val_accuracy: 0.8724
# Epoch 19/20
# 1852/1875 [============================>.] - ETA: 0s - loss: 1.0966 - accuracy: 0.8672NUMBER OF EPOCHS: 19
#
# Epoch 19: Average scale value of w: 2.391880750656128,Average scale value of b: 12.18303108215332, Loss: 1.0951169729232788, Accuracy: 0.8669333457946777
# NUMBER OF EPOCHS: 19
#
# Epoch 19: Average scale value of w: 3.4566726684570312,Average scale value of b: 2.360750675201416, Loss: 1.0951169729232788, Accuracy: 0.8669333457946777
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0951 - accuracy: 0.8669 - val_loss: 1.3168 - val_accuracy: 0.8046
# Epoch 20/20
# 1852/1875 [============================>.] - ETA: 0s - loss: 1.0783 - accuracy: 0.8655NUMBER OF EPOCHS: 20
#
# Epoch 20: Average scale value of w: 2.592385768890381,Average scale value of b: 13.459818840026855, Loss: 1.0782222747802734, Accuracy: 0.8652166724205017
# NUMBER OF EPOCHS: 20
#
# Epoch 20: Average scale value of w: 3.8227241039276123,Average scale value of b: 2.552659749984741, Loss: 1.0782222747802734, Accuracy: 0.8652166724205017
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0782 - accuracy: 0.8652 - val_loss: 1.2345 - val_accuracy: 0.8772
# 313/313 [==============================] - 0s 626us/step - loss: 1.2345 - accuracy: 0.8772
# Quantized Model Test Accuracy: 0.8772000074386597
# /var/folders/ms/xd16k27j2lj0dx3xp_nqkcgr0000gn/T/ipykernel_811/76854052.py:46: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/ms/xd16k27j2lj0dx3xp_nqkcgr0000gn/T/ipykernel_811/76854052.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
